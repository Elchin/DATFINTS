# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import datfints_utils as df_utils
#from pandas.plotting import scatter_matrix
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_utils.calc_rsi('ETH-USD','2021-1-1')
df_utils.calc_rsi('TSLA','2021-1-1')
df_utils.calc_rsi('BTC-USD','2021-1-1')

# %%
price=df_utils.stock_price_prediction('BTC-USD','2019-1-1')
print('min, mean, max:',
      round(min(price),1),round(np.mean(price),1),round(max(price),1))
# Out:
# Linear Regression Confidence: 0.9654509925925729
# min, mean, max: 34862.8 37499.5 40908.9

# %%
plt.plot(price)
plt.title('12 days price prediction')
plt.xlabel('Time [days]')
plt.ylabel('Price [$]')
# Out:
# Text(0, 0.5, 'Price [$]')
